# %%
import pandas as pd
import numpy as np
features = pd.read_csv('shared_data/features.csv')

# %%
features.head(10)
# Out:
#    Unnamed: 0  venue_id   latitude  longitude  density  neighbors_entropy  \
# 0           0   59479.0  40.646133  -73.90315     20.0           4.510825
# 1           1     162.0  40.700645  -73.94293     43.0           5.007660
# 2           2   50006.0  40.702366  -74.01126    126.0           7.167056
# 3           3   14304.0  40.745537  -73.90356     72.0           9.535595
# 4           4     488.0  40.827675  -73.92475     57.0           9.606036
# 5           5     817.0  40.746216  -73.61775     29.0           4.395682
# 6           6   79385.0  40.700405  -73.81420      5.0           1.921928
# 7           7    1226.0  40.702248  -73.79154      8.0           2.750000
# 8           8    1437.0  40.870617  -73.84654     10.0           3.654121
# 9           9    1512.0  40.741860  -73.64054     27.0           7.230187
#
#    competitiveness  area_popularity  transition_density  incoming_flow  \
# 0        -0.100000            171.0                37.0           53.0
# ...
